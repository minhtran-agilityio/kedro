# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import altair as alt

# %reload_ext autoreload
# %autoreload 2
# %reload_kedro
# Out:
# 2021-01-05 16:41:47,224 - kedro.framework.session.store - INFO - `read()` not implemented for `BaseSessionStore`. Assuming empty store.
# /Users/minhtran/Documents/WORK/training/minhtran/data-learning/kedro/env-kedro/lib/python3.8/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# 2021-01-05 16:41:47,334 - root - INFO - ** Kedro project spaceflights
# 2021-01-05 16:41:47,335 - root - INFO - Defined global variable `context`, `session` and `catalog`
# 2021-01-05 16:41:47,343 - root - INFO - Registered line magic `run_viz`

# %%
mk_df = catalog.load("marketing")
mk_df.head()
# Out:
# 2021-01-05 16:41:49,450 - kedro.io.data_catalog - INFO - Loading data from `marketing` (CSVDataSet)...
# /Users/minhtran/Documents/WORK/training/minhtran/data-learning/kedro/env-kedro/lib/python3.8/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#       Age  Gender OwnHome  Married Location  Salary  Children History  \
# 0     Old  Female     Own   Single      Far   47500         0    High
# 1  Middle    Male    Rent   Single    Close   63600         0    High
# 2   Young  Female    Rent   Single    Close   13500         0     Low
# 3  Middle    Male     Own  Married    Close   85600         1    High
# 4  Middle  Female     Own   Single    Close   68400         0    High
#
#    Catalogs  AmountSpent
# 0         6          755
# 1         6         1318
# 2        18          296
# 3        18         2436
# 4        12         1304

# %%
(alt.
    Chart(mk_df).
    mark_circle(size=50).
    encode(x='Salary', y='AmountSpent', color='Age')
)
# Out:
# 2021-01-05 16:43:16,865 - numexpr.utils - INFO - NumExpr defaulting to 4 threads.
# alt.Chart(...)

# %%
(alt.
  Chart(mk_df).
  mark_circle(size=50).
  encode(x='Salary', y='AmountSpent', color='Age').
  transform_filter(alt.FieldLTPredicate(field='Salary', lt=120000)).
  properties(height=400, width=500))
# Out:
# alt.Chart(...)
